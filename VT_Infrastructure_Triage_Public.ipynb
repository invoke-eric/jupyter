# %% [markdown]
# # Imports and Setup

# %%
import requests
import sys
import re
import json
import pandas as pd
import datetime

# %% [markdown]
# never save your api key to a script you push to a public repo :)

# %%
with open('/path/to/file/containing/vt/api/key') as f:
    key = f.read()

# %%
request_headers = {
    'x-apikey': key.strip(),
}

# %%
ipregex = re.compile(r'(?:(?:\d|[01]?\d\d|2[0-4]\d|25[0-5])\.){3}(?:25[0-5]|2[0-4]\d|[01]?\d\d|\d)(?:\/\d{1,2})?')
domainregex = re.compile(r'\b((?=[a-z0-9-]{1,63}\.)(xn--)?[a-z0-9]+(-[a-z0-9]+)*\.)+[a-z]{2,63}\b')
iplist = []
domainlist = []

# %% [markdown]
# # Input

# %%
with open('domains.txt') as f:
    infr_list = f.readlines()
    
for line in infr_list:
    line = line.strip()
    
    match_ipregex = ipregex.match(line)
    if match_ipregex:
        iplist.append(line)
    
    match_domainregex = domainregex.match(line)

    if match_domainregex:
        domainlist.append(line)

    elif not match_ipregex and not match_domainregex:
        print(line + " is probably not a domain or an IP")

# %% [markdown]
# # Domain Queries

# %%
# set up blank dataframes to hold all of our responses
main_domain_df = pd.DataFrame()
main_communicating_df = pd.DataFrame()
main_downloaded_df = pd.DataFrame()

# %% [markdown]
# ### Query /domains endpoint

# %%
for domain in domainlist:
    try:
        url = "https://www.virustotal.com/api/v3/domains/" + domain
        r = requests.get(url, headers=request_headers)
        domain_data = r.json()
        
        df = pd.json_normalize(domain_data)
        df['domain'] = domain
        
        df = r.json()
        df = pd.json_normalize(df)
        df['domain'] = domain
        df['last_dns_records_human'] = pd.to_datetime(df['data.attributes.last_dns_records_date'], unit='s')
        df['last_update_date_human'] = pd.to_datetime(df['data.attributes.last_update_date'], unit='s')
        df['data.attributes.creation_date_human'] = pd.to_datetime(df['data.attributes.creation_date'], unit='s')
        main_domain_df  = pd.concat([main_domain_df, df])
        trimmed_df = main_domain_df[['domain', 'data.attributes.last_analysis_stats.malicious', 'last_dns_records_human','last_update_date_human', 'data.attributes.creation_date_human'] ]
    except:
        print("Error creating main domain df for " + domain)

# %%
main_domain_df[['domain', 'data.attributes.last_analysis_stats.malicious', 'last_dns_records_human','last_update_date_human', 'data.attributes.creation_date_human'] ]
# Out:
#                    domain  data.attributes.last_analysis_stats.malicious  \
# 0       bigdaddy.ddns.net                                              4
# 0    1biggie.publicvm.com                                             11
# 0    n0fuzga.publicvm.com                                             10
# 0  daveblack.publicvm.com                                             11
# 0      sky01.publicvm.com                                             12
# 0    franc01.publicvm.com                                             11
# 0  bbrainx01.publicvm.com                                              9
#
#   last_dns_records_human last_update_date_human  \
# 0    2022-04-21 17:05:31    2022-01-13 00:36:17
# 0    2022-07-22 10:54:37    2022-07-20 07:03:58
# 0    2022-07-20 06:35:20    2022-07-20 07:03:58
# 0    2022-05-27 12:17:17    2022-07-20 07:03:58
# 0    2022-07-14 06:41:47    2022-07-20 07:03:58
# 0    2022-06-17 02:07:43    2022-07-20 07:03:58
# 0    2022-07-22 22:46:24    2022-07-20 07:03:58
#
#   data.attributes.creation_date_human
# 0                 2001-06-28 16:04:59
# 0                 2007-07-19 05:57:17
# 0                 2007-07-19 05:57:17
# 0                 2007-07-19 05:57:17
# 0                 2007-07-19 05:57:17
# 0                 2007-07-19 05:57:17
# 0                 2007-07-19 05:57:17

# %% [markdown]
# ### Query /communicating_files Endpoint

# %%
for domain in domainlist:
    try:
        url = "https://www.virustotal.com/api/v3/domains/" + domain + "/communicating_files?limit=50" 
        # if you do not specify a limit parameter, the default value is 10
        r = requests.get(url, headers=request_headers)
        communicating_data = r.json()
    except:
        print("Couldn't reach VT for " + domain)  
    
    try:
        df = pd.json_normalize(communicating_data)
        df['domain'] = domain
        df = df.explode('data')
        df = df.reset_index()
        data = [x for x in df['data']]
        df2 = pd.concat([df.drop('data', axis=1), pd.json_normalize(data)], axis=1)
      
        df3 = df2[['domain', 'attributes.sha256', 'attributes.last_analysis_stats.malicious', 'attributes.first_submission_date', 'attributes.size'
           , 'attributes.names', 'attributes.type_description', 'attributes.type_extension']]

    except:
        print("couldn't create df for " + domain)
        # this will happen if there are no communicating files
    try:
        main_communicating_df = pd.concat([main_communicating_df, df3], axis=0)
    except:
        print("couldn't concatenate for " + domain)
# Out:
# couldn't create df for bbrainx01.publicvm.com

# %%
main_communicating_df['first_submission_date'] = pd.to_datetime(main_communicating_df['attributes.first_submission_date'], unit='s')
main_communicating_df = main_communicating_df.drop(columns=['attributes.first_submission_date'])

# %% [markdown]
# #### Display results

# %%
main_communicating_df.sort_values(by=['first_submission_date'], ascending=False)
# Out:
#                    domain                                  attributes.sha256  \
# 1    franc01.publicvm.com  df9ff33718bab1bc71c2736165731d3ef59d8164fa2637...
# 1    franc01.publicvm.com  df9ff33718bab1bc71c2736165731d3ef59d8164fa2637...
# 4      sky01.publicvm.com  5968c3e2838932293e0bef478f3b150fb767dbf26ab13d...
# 0    franc01.publicvm.com  4530c2681887c0748cc2ecddb1976d15ad813a4a01e581...
# 0    franc01.publicvm.com  4530c2681887c0748cc2ecddb1976d15ad813a4a01e581...
# 8    1biggie.publicvm.com  d4ae6077f8161e5f7e1ba8c6728bd3ef0d27953d932f48...
# 4  daveblack.publicvm.com  ddfca42d6eb175f5a48463f09f165fa2f5e8aa8060327a...
# 7      sky01.publicvm.com  778975d324970c8ac14b1257fa51ac86c24b825e0e0c19...
# 2    1biggie.publicvm.com  2bb4bb6851ef659b9bb891e22718c5b76fde4a9041d6de...
# 6      sky01.publicvm.com  648b3c64a26754d82cb20eaa5bc42b96b0d5874f61bb71...
# 2      sky01.publicvm.com  2d1776ded8975eacf570bbcf2dfc3574eb0b3fc34dc6a8...
# 5    1biggie.publicvm.com  8619da4e5b3beeb2da6931f2f2f7dd468eaf59c725ec7e...
# 0  daveblack.publicvm.com  45a8b81aa37f2fe40c055f7d2b3692882586d4628a94c9...
# 4    1biggie.publicvm.com  77a3e1f54ca2e2d4212f4053695d23d3c7700421433778...
# 3    1biggie.publicvm.com  593fd9a7e2993e2576fa546b6cf4c15880929906f74944...
# 0       bigdaddy.ddns.net  2f99361d0b3149581ca08eaa303a67b4cc17d1e9a4a4e5...
# 1  daveblack.publicvm.com  5edab639e92f02d7a8037b70b057b3a672c2b417647f2c...
# 6    1biggie.publicvm.com  9d4beb761039c963c2fb5368e2d45c67b88deaabf5e5be...
# 1    1biggie.publicvm.com  2581d4cdd3f2140c1950ecbfed6db9a2aef7fe97e2a854...
# 3  daveblack.publicvm.com  9fde267097676a0dd98067349f700115cfc2d2b7c679de...
# 7    1biggie.publicvm.com  b104a0be8bc563c1c25cbdf9cbef633f963d7b07ca8ea5...
# 0    1biggie.publicvm.com  0c97af471582274a045b455599ac8ada4e61716a02bbaf...
# 5      sky01.publicvm.com  5d2a0ca22f2f9cee131a709def23b84fabf3bd18f0bad6...
# 0    n0fuzga.publicvm.com  e0e3c47d0f6841834a2a8357d46c8f4ac24964140c3699...
# 2  daveblack.publicvm.com  6f460e24d9d49b09f6836b328bb826854e8d1751091070...
# 5  daveblack.publicvm.com  ef278d92bb133cf0bae780112c068f97332690de339909...
# 9      sky01.publicvm.com  cfe65a88ebc858c083c6bfd48d1caf16128a420d9352b4...
# 1      sky01.publicvm.com  2c9a58ee77f97340bd1d03762d39ffbc324da6e9c853cd...
# 1       bigdaddy.ddns.net  f8546d4051c50ef7e38897725dca47b2df4e1d5125e22b...
# 8      sky01.publicvm.com  c0d543e1424136cf18df4def6132a46a5dbd495d562f03...
# 0      sky01.publicvm.com  04f1167fc18a3a7b045969cc76dbed4da5367f01207260...
# 3      sky01.publicvm.com  2ddcc6b97e877272b6ddb96250dbd667773f7adce1a78d...
#
#    attributes.last_analysis_stats.malicious  attributes.size  \
# 1                                        19           216068
# 1                                        19           216068
# 4                                        19           216094
# 0                                        53            48640
# 0                                        53            48640
# 8                                        24            72295
# 4                                        55            48640
# 7                                        46            48672
# 2                                        18            13288
# 6                                        23            72378
# 2                                        26            13288
# 5                                        22            72360
# 0                                        14            72323
# 4                                        21            72357
# 3                                        20            54583
# 0                                        12            65275
# 1                                        12           111175
# 6                                        18            72475
# 1                                        58            48640
# 3                                        24           122708
# 7                                        23           122648
# 0                                         4            77144
# 5                                         4            34844
# 0                                        47            48640
# 2                                        49            48641
# 5                                        25            34344
# 9                                        57            48640
# 1                                         2            46683
# 1                                        13            92824
# 8                                        22            30904
# 0                                        13            54975
# 3                                        26            45617
#
#                                     attributes.names  \
# 1               [CrpFRaNCVOp0.vbs, crpfrancvop0.vbs]
# 1               [CrpFRaNCVOp0.vbs, crpfrancvop0.vbs]
# 4  [c:\windows\system32\afd1ndpmx.dll, c:\windows...
# 0               [Client.exe, stage3_InstallUtil.exe]
# 0               [Client.exe, stage3_InstallUtil.exe]
# 8  [d4ae6077f8161e5f7e1ba8c6728bd3ef0d27953d932f4...
# 4                          [Client.exe, malware.exe]
# 7  [virus\c622227b1b8e8b564b113d902593c498, Clien...
# 2                  [Aircraft A320 Slide PN# (1).vbs]
# 6  [C:\Users\Public\jqdr1ev4ly.PS1, 648b3c64a2675...
# 2  [01_samples_for_upload\047.vir, 2d1776ded8975e...
# 5  [content.27377.22792.21929.22857.3102, C:\User...
# 0                              [mal.ps1, junb92wo9g]
# 4                       [ol7eo3mrte, ol7eo3mrte.PS1]
# 3                        [unknown, PO_915273015.vbs]
# 0                              [#ANO23697654567.vbs]
# 1             [./Aircraft PN#.vbs, Aircraft PN#.vbs]
# 6                   [Aircraft PN#_&_Qty Details.vbs]
# 1  [Client.exe, c:\windows\system32\yyas95sru.dll...
# 3  [content.9901.20920.21407.19082.19752, C:\User...
# 7  [C:\Users\Public\ppbxas4bjb.PS1, b104a0be8bc56...
# 0  [0c97af471582274a045b455599ac8ada4e61716a02bba...
# 5                         [List of Aircraft PN#.vbs]
# 0                         [Client.exe, dlpaste4.exe]
# 2                                       [Client.exe]
# 5  [FlightConfirmation Details.vbs, FlightConfirm...
# 9  [Client.exe, our_rat_decoded.dll, c:\windows\s...
# 1    [List of Chemicals & Specification Details.vbs]
# 1            [Nw PN #23069746XVNXH8W630HXFRATQH.vbs]
# 8  [c:\windows\system32\dg1pen9rc.dll, c:\windows...
# 0  [Updated Passenger Trip Sheet.vbs";filename*=U...
# 3  [2ddcc6b97e877272b6ddb96250dbd667773f7adce1a78...
#
#   attributes.type_description attributes.type_extension first_submission_date
# 1                     unknown                       NaN   2022-06-13 17:46:22
# 1                     unknown                       NaN   2022-06-13 17:46:22
# 4                     unknown                       NaN   2022-06-13 16:42:18
# 0                   Win32 EXE                       exe   2022-05-18 15:39:56
# 0                   Win32 EXE                       exe   2022-05-18 15:39:56
# 8                  Powershell                       ps1   2022-05-11 21:50:32
# 4                   Win32 EXE                       exe   2022-05-05 21:24:29
# 7                   Win32 EXE                       exe   2022-04-28 03:28:13
# 2                         VBA                       vbs   2022-04-27 18:34:46
# 6                  Powershell                       ps1   2022-04-27 17:04:26
# 2                         VBA                       vbs   2022-04-27 17:03:59
# 5                  Powershell                       ps1   2022-04-25 17:31:58
# 0                  Powershell                       ps1   2022-04-25 16:14:47
# 4                  Powershell                       ps1   2022-04-25 15:25:29
# 3                         VBA                       vbs   2022-04-25 15:18:14
# 0                         VBA                       vbs   2022-04-21 16:52:46
# 1                         VBA                       vbs   2022-04-21 13:47:56
# 6                         VBA                       vbs   2022-04-21 12:29:13
# 1                   Win32 EXE                       exe   2022-04-21 12:07:12
# 3                  Powershell                       ps1   2022-04-20 12:33:12
# 7                  Powershell                       ps1   2022-04-20 07:47:23
# 0                  JavaScript                        js   2022-04-20 07:47:10
# 5                  JavaScript                        js   2022-04-20 02:01:04
# 0                   Win32 EXE                       exe   2022-04-19 12:42:26
# 2                   Win32 EXE                       exe   2022-04-19 12:42:08
# 5                  JavaScript                        js   2022-04-12 22:20:08
# 9                   Win32 EXE                       exe   2022-04-12 20:47:09
# 1                  JavaScript                        js   2022-04-12 15:49:10
# 1                  JavaScript                        js   2022-04-11 18:40:22
# 8                  JavaScript                        js   2022-04-11 15:17:22
# 0                  JavaScript                        js   2022-04-08 18:10:21
# 3                  JavaScript                        js   2022-04-07 17:50:12

# %% [markdown]
# ### Query /downloaded_files Endpoint

# %%
for domain in domainlist:
    try:
        url = "https://www.virustotal.com/api/v3/domains/" + domain + "/downloaded_files?limit=39"
        # the API returns an error for limit values above 40
        r = requests.get(url, headers=request_headers)
        downloaded_data = r.json()
    except:
        print("Couldn't reach VT for " + domain)  
    
    try:
        df = pd.json_normalize(downloaded_data)
        df['domain'] = domain
        df = df.explode('data')
        df = df.reset_index()
        data = [x for x in df['data']]
        df2 = pd.concat([df.drop('data', axis=1), pd.json_normalize(data)], axis=1)
      
        df3 = df2[['domain', 'attributes.sha256', 'attributes.last_analysis_stats.malicious', 'attributes.first_submission_date', 'attributes.size'
           , 'attributes.names', 'attributes.type_description', 'attributes.type_extension']]
    except:
        print("couldn't create df for " + domain)
        # this will happen if there are no downloaded files
    try:
        main_downloaded_df = pd.concat([main_downloaded_df, df3], axis=0)
    except:
        print("couldn't concatenate for " + domain)
# Out:
# couldn't create df for 1biggie.publicvm.com
# couldn't create df for n0fuzga.publicvm.com
# couldn't create df for daveblack.publicvm.com
# couldn't create df for sky01.publicvm.com
# couldn't create df for franc01.publicvm.com
# couldn't create df for bbrainx01.publicvm.com

# %%
main_downloaded_df['first_submission_date'] = pd.to_datetime(main_downloaded_df['attributes.first_submission_date'], unit='s')
main_downloaded_df = main_downloaded_df.drop(columns=['attributes.first_submission_date'])

# %% [markdown]
# #### Display Results

# %%
main_downloaded_df.sort_values(by=['first_submission_date'], ascending=False)
# Out:
#               domain                                  attributes.sha256  \
# 0  bigdaddy.ddns.net  1c0ec2d553a1a5d8f81a038316f82e5e4d77d7fd377f56...
# 0  bigdaddy.ddns.net  1c0ec2d553a1a5d8f81a038316f82e5e4d77d7fd377f56...
# 0  bigdaddy.ddns.net  1c0ec2d553a1a5d8f81a038316f82e5e4d77d7fd377f56...
# 0  bigdaddy.ddns.net  1c0ec2d553a1a5d8f81a038316f82e5e4d77d7fd377f56...
# 0  bigdaddy.ddns.net  1c0ec2d553a1a5d8f81a038316f82e5e4d77d7fd377f56...
# 0  bigdaddy.ddns.net  1c0ec2d553a1a5d8f81a038316f82e5e4d77d7fd377f56...
# 0  bigdaddy.ddns.net  1c0ec2d553a1a5d8f81a038316f82e5e4d77d7fd377f56...
#
#    attributes.last_analysis_stats.malicious  attributes.size  \
# 0                                         0             7577
# 0                                         0             7577
# 0                                         0             7577
# 0                                         0             7577
# 0                                         0             7577
# 0                                         0             7577
# 0                                         0             7577
#
#                                     attributes.names  \
# 0  [/var/www/clean-mx/virusesevidence/output.1760...
# 0  [/var/www/clean-mx/virusesevidence/output.1760...
# 0  [/var/www/clean-mx/virusesevidence/output.1760...
# 0  [/var/www/clean-mx/virusesevidence/output.1760...
# 0  [/var/www/clean-mx/virusesevidence/output.1760...
# 0  [/var/www/clean-mx/virusesevidence/output.1760...
# 0  [/var/www/clean-mx/virusesevidence/output.1760...
#
#   attributes.type_description attributes.type_extension first_submission_date
# 0                        HTML                      html   2021-07-17 04:25:07
# 0                        HTML                      html   2021-07-17 04:25:07
# 0                        HTML                      html   2021-07-17 04:25:07
# 0                        HTML                      html   2021-07-17 04:25:07
# 0                        HTML                      html   2021-07-17 04:25:07
# 0                        HTML                      html   2021-07-17 04:25:07
# 0                        HTML                      html   2021-07-17 04:25:07

# %% [markdown]
# # IP Queries

# %%
# create blank DataFrames to hold our responses
main_ip_df = pd.DataFrame()
main_ip_communicating_df = pd.DataFrame()
main_ip_downloaded_df = pd.DataFrame()

# %% [markdown]
# ### Query /ip_addresses/ Endpoint

# %%
for ip in iplist:
    try:
        
        url = "https://www.virustotal.com/api/v3/ip_addresses/" + ip
        r = requests.get(url, headers=request_headers)
    except:
        print("Couldn't reach VT for " + ip)  
    
    try:
        ip_data = r.json()
        
        df = pd.json_normalize(ip_data)
        df2 = df[['data.id', 'data.attributes.last_analysis_stats.malicious', 'data.attributes.whois_date', 'data.attributes.last_modification_date']]

    
    except:
        print("couldn't create df for " + ip)
    try:
        main_ip_df = pd.concat([main_ip_df, df2])
    except:
        print("couldn't concatenate for " + ip)

# %%
main_ip_df['whois_date_human'] = pd.to_datetime(main_ip_df['data.attributes.whois_date'], unit='s')
main_ip_df['last_modification_date_human'] = pd.to_datetime(main_ip_df['data.attributes.last_modification_date'], unit='s')
main_ip_df = main_ip_df.drop(columns=['data.attributes.last_modification_date', 'data.attributes.whois_date'])

# %% [markdown]
# #### Display Results

# %%
main_ip_df
# Out:
#          data.id  data.attributes.last_analysis_stats.malicious  \
# 0  104.21.29.171                                              0
#
#      whois_date_human last_modification_date_human
# 0 2022-08-18 13:14:18          2022-08-19 18:16:40

# %% [markdown]
# ### Query /communicating_files Endpoint

# %%
for ip in iplist:
    try:
        url = "https://www.virustotal.com/api/v3/ip_addresses/" + ip + "/communicating_files?limit=50"
        # as noted above, limit parameter defaults to 10 if you do not specify it
        r = requests.get(url, headers=request_headers)
    except:
        print("Couldn't reach VT for " + ip)  
    
    try:
        communicating_data = r.json()

        df = pd.json_normalize(communicating_data)
        df['ip'] = ip
        df = df.explode('data')
        df = df.reset_index()
        data = [x for x in df['data']]
        df2 = pd.concat([df.drop('data', axis=1), pd.json_normalize(data)], axis=1)
      
        df3 = df2[['ip', 'attributes.sha256', 'attributes.last_analysis_stats.malicious', 'attributes.first_submission_date', 'attributes.size'
           , 'attributes.names', 'attributes.type_description', 'attributes.type_extension']]

    except:
        print("couldn't create df for " + ip)
        # as noted above, this will happen if there are no communicating files
    try:
        main_ip_communicating_df = pd.concat([main_ip_communicating_df, df3], axis=0)
    except:
        print("couldn't concatenate for " + ip)

# %%
main_ip_communicating_df['first_submission_date'] = pd.to_datetime(main_ip_communicating_df['attributes.first_submission_date'], unit='s')
main_ip_communicating_df = main_ip_communicating_df.drop(columns=['attributes.first_submission_date'])

# %% [markdown]
# #### Display Results

# %%
main_ip_communicating_df.sort_values(by=['first_submission_date'], ascending=False)
# Out:
#                ip                                  attributes.sha256  \
# 11  104.21.29.171  f8996298d0902b91d8f09ce66ba73022501972f4830ee3...
# 2   104.21.29.171  26a333685c8cd8223048006f279d1b4de589da4d0e42f0...
# 8   104.21.29.171  bc6bd1def1fc60aa1221a6a4c6cfee3dcbb3422ecd12b4...
# 9   104.21.29.171  d0a2cbef067e9c7e2100032a06f042bd668ff08f2d114b...
# 4   104.21.29.171  6e9857ba9a3a3427f69a80e71feec70a27c543f47f3a1b...
# 5   104.21.29.171  772e3824d39e6c3c995e83addc88af6ae9956a229bc65b...
# 0   104.21.29.171  0ab5c3556818b25c3d59b895b72d0ce3da5e6564b935d5...
# 7   104.21.29.171  99c2076b437eccdd3f5503b1af6f3bb518fc5f65d094ff...
# 6   104.21.29.171  7a468a9e7c3e9d7f9435fb47bf92bf1e608736830e201e...
# 3   104.21.29.171  575ebd0f99c90abc92e4cf10c7c253ed46430312cf3fd4...
# 10  104.21.29.171  e4301ab01af39f6e21558c669bd804247cc734fcd8a834...
# 1   104.21.29.171  0eb513006bfa3930709f8cf499b58f4bb3f358373c06f5...
#
#     attributes.last_analysis_stats.malicious  attributes.size  \
# 11                                         0          2418109
# 2                                          1          6594045
# 8                                          0          4116954
# 9                                         21            28565
# 4                                         53           460880
# 5                                          3          1126400
# 0                                         21          1081858
# 7                                          4          1130496
# 6                                          5          1125888
# 3                                          3           222425
# 10                                        32          2579900
# 1                                         35          2578279
#
#                                      attributes.names  \
# 11                         [WLW #2 - by ROI Team.pdf]
# 2                                                  []
# 8                                                  []
# 9                                                  []
# 4            [08e85f10ab7bb7832bd8724c72ade987.virus]
# 5                                  [MasterSeeker.exe]
# 0                                                  []
# 7   [d:\my downloads\masterseeker1.5.1\masterseeke...
# 6   [MasterSeeker.exe, masterseeker.exe, %temp%\ra...
# 3                                           [pkg.apk]
# 10  [Anti_Busted_2009, c:/aa/aa, C:\YAo4aMSOB\3RIw...
# 1     [c:/aa/aa, C:\oklBZ\yImSkZ\xsr7a8Pi\usBk5.dotx]
#
#    attributes.type_description attributes.type_extension first_submission_date
# 11                         PDF                       pdf   2022-06-03 08:02:31
# 2                      Android                       apk   2022-05-31 06:39:33
# 8                      Android                       apk   2022-04-03 07:23:10
# 9                         HTML                      html   2022-01-22 12:09:25
# 4                    Win32 EXE                       exe   2021-12-15 05:45:12
# 5                    Win32 EXE                       exe   2021-11-14 16:19:04
# 0                    Win32 EXE                       exe   2021-11-04 17:29:23
# 7                    Win32 EXE                       exe   2014-09-28 05:20:13
# 6                    Win32 EXE                       exe   2014-06-27 23:01:54
# 3                      Android                       apk   2013-05-06 20:36:50
# 10                   Win32 EXE                       exe   2009-06-12 17:20:26
# 1                    Win32 EXE                       exe   2009-06-06 17:09:36

# %% [markdown]
# ### Query /downloaded_files Endpoint

# %%
for ip in iplist:
    try:
        url = "https://www.virustotal.com/api/v3/ip_addresses/" + ip + "/downloaded_files?limit=39"
        # as noted above, API returns error for values above 40
        r = requests.get(url, headers=request_headers)
    except:
        print("Couldn't reach VT for " + ip)  
    
    try:
        downloaded_data = r.json()

        df = pd.json_normalize(downloaded_data)
        df['ip'] = ip
        df = df.explode('data')
        df = df.reset_index()
        data = [x for x in df['data']]
        df2 = pd.concat([df.drop('data', axis=1), pd.json_normalize(data)], axis=1)
      
        df3 = df2[['ip', 'attributes.sha256', 'attributes.last_analysis_stats.malicious', 'attributes.first_submission_date', 'attributes.size'
           , 'attributes.names', 'attributes.type_description', 'attributes.type_extension']]

    except:
        print("couldn't create df for " + ip)
        # as noted aboce, this will happen if there are no downloaded files
    try:
        main_ip_downloaded_df = pd.concat([main_ip_downloaded_df, df3], axis=0)
    except:
        print("couldn't concatenate for " + ip)

# %%
main_ip_downloaded_df['first_submission_date'] = pd.to_datetime(main_ip_downloaded_df['attributes.first_submission_date'], unit='s')
main_ip_downloaded_df = main_ip_downloaded_df.drop(columns=['attributes.first_submission_date'])

# %% [markdown]
# #### Display Results

# %%
main_ip_downloaded_df.sort_values(by=['first_submission_date'], ascending=False)
# Out:
#                ip                                  attributes.sha256  \
# 7   104.21.29.171  ab65e678e0ee57b9ef8c13e5734a7613001e1f1a9c9fa4...
# 11  104.21.29.171  daff297fba433d9c199953fb523ceb3e9853f0551b7ff2...
# 6   104.21.29.171  4d5692811dd085633084b6215bee8662fe5e7526b64b1c...
# 14  104.21.29.171  1d50d1dfef532616fba62aa28d0395adb48ea2a6c2309d...
# 15  104.21.29.171  f4b23099c59175ebd416ec39a63db9d293def0c61514eb...
# 9   104.21.29.171  76bc83158e2d5946f5b6199c1805c8ffecd1757227a87e...
# 18  104.21.29.171  da01d82c3cd416b4663aff1698a4077d3d54e7c6f4dc21...
# 19  104.21.29.171  86edb184f2347fde21ca9914b8a8b46403c46a5908eba1...
# 13  104.21.29.171  432280ce32b853953f5b84301b20a0d6708c91912c89fc...
# 16  104.21.29.171  2b89a16e76690b72d3b5d4ff10b7e722734962971886bb...
# 20  104.21.29.171  197d7194a95069730423ac53bdc7972a4abf66d57b0719...
# 12  104.21.29.171  246e9b98294c5d4d3b2eff95fee8a7be973638006c56cf...
# 23  104.21.29.171  fe8343e9f6eafaf6f1f2987a856eeca9b8fdf2c944a9f3...
# 29  104.21.29.171  a05ffbd7f430d444e5b5a6f1514c85ed48118277952c50...
# 22  104.21.29.171  66932d5908650aebc2731d11d32f66a0017c470518e505...
# 17  104.21.29.171  9f90cf0254dd0424ee6432941c25ba2222070a56780cd5...
# 0   104.21.29.171  1bf6c98d6ce7fad36d7a48fcf3d04d1e02d1307a8ee04e...
# 33  104.21.29.171  fd75e75949375e9430bf75af1322469e0b2dcd2501ce14...
# 25  104.21.29.171  2bd204be31f5f03f2ac8a2c1bf1593ac5466f229bd7d65...
# 28  104.21.29.171  53362111d0ec0156a5a3a7e331f49d0543215caf3ee5d9...
# 4   104.21.29.171  ea576e1aa8386f349640e71fb341dceb92b50b1b1edd19...
# 21  104.21.29.171  8437bd0ef46a19c9a7c294c53e0429b40e76ebbd5fe9fd...
# 35  104.21.29.171  eaecade51efd673003ffb78fc518d06cbf068407296447...
# 38  104.21.29.171  fa91d35d6959152baf29dae7583d4d24489628048c356b...
# 1   104.21.29.171  6dbfab0a5424fb49d6ebfdc763a0b0d6982f51ca23192f...
# 37  104.21.29.171  230d91b44ffd4de6a3cfe521b2560e5ed59763df51a5de...
# 8   104.21.29.171  a980b60a8922f510d2da527e74ec9443a57dcc65444dbd...
# 24  104.21.29.171  258682bcb3d7d927aaf47bfe1c01788db1f0cda4bf2240...
# 26  104.21.29.171  7a6fd962b4686f8277823b26cda79726ee97abc0c7f649...
# 31  104.21.29.171  25fb23868ebf48348f9e438e00cb9b9d9b3a054f32482a...
# 5   104.21.29.171  d465172175d35d493fb1633e237700022bd849fa123164...
# 32  104.21.29.171  d106d2c5afe35e691b9d24cf6a8ae790ea8f0aee7e7c7d...
# 34  104.21.29.171  d11dc22c73306cd84bc9869302b02dc8604d596185203a...
# 30  104.21.29.171  302c2ee086c23039d204712bf2c05277bd7c0f28cb08f6...
# 3   104.21.29.171  ef70397570ecbdbd7c74298dc22538f6e50f74c6520927...
# 10  104.21.29.171  e1083bab4b7e89f0e7006e12a644c2d3096663461603cf...
# 2   104.21.29.171  6b3c238ebcf1f3c07cf0e556faa82c6b8fe96840ff4b6b...
# 27  104.21.29.171  7d04f7431bbfa41a04bcc7e6b98b9de0d919756c4c671c...
# 36  104.21.29.171  6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
#
#     attributes.last_analysis_stats.malicious  attributes.size  \
# 7                                          0             7109
# 11                                         0             2443
# 6                                          0            45659
# 14                                         0            79469
# 15                                         0             7109
# 9                                          0              932
# 18                                         0             7109
# 19                                         0             7109
# 13                                         0            81138
# 16                                         0             2714
# 20                                         0             1785
# 12                                         0              423
# 23                                         0            23089
# 29                                         0            43962
# 22                                         0             3741
# 17                                         0               53
# 0                                         17           122132
# 33                                         0              131
# 25                                         0              419
# 28                                         0              273
# 4                                          0             1412
# 21                                         0             6609
# 35                                         0               21
# 38                                         0              593
# 1                                          1              555
# 37                                         0             1236
# 8                                          0              552
# 24                                         0             1552
# 26                                         0              145
# 31                                         0              548
# 5                                          0              548
# 32                                         0              179
# 34                                         0              494
# 30                                         0              148
# 3                                          0              614
# 10                                         0             1091
# 2                                          0                3
# 27                                         0               13
# 36                                         0                1
#
#                                      attributes.names  \
# 7   [762910965691187210, 706860923255783454, 97841...
# 11                            [sliders, /api/sliders]
# 6   [/var/www/clean-mx/virusesevidence/output.1965...
# 14  [/var/www/clean-mx/virusesevidence/output.1956...
# 15  [905834303391424512, 807915967031541762, share...
# 9                                          [goto.php]
# 18  [920558096424771594, 951452297072873522, 87410...
# 19  [858716014715469864, 821829564962832424, 68879...
# 13                                                 []
# 16                                                 []
# 20                                                 []
# 12                       [hotsexmovs.com-header.html]
# 23  [/var/www/clean-mx/virusesevidence/output.1800...
# 29  [/var/www/clean-mx/virusesevidence/output.1780...
# 22  [/var/www/clean-mx/virusesevidence/output.1758...
# 17  [/var/www/clean-mx/virusesevidence/output.1801...
# 0   [/var/www/clean-mx/virusesevidence/output.1745...
# 33                                                 []
# 25  [eni9, gylj3v7jsre3dpiyjagam6ljf7rfekzybvqq==&...
# 28                                                 []
# 4   [index.php, /var/www/clean-mx/virusesevidence/...
# 21  [find, eyJpdiI6Ind4YmdtVWZjN1dKbEY3VE9uNEc0WGc...
# 35  [horsedetails.cfm, /tmp/tmpVtc7jO.tmp, /tmp/tm...
# 38  [topicsbt_1.htm, 3UpP1d8wHiOhDN1JtVSh_16_c6892...
# 1   [l23, l28, l62, tr-en, l83, wp-login.php, l11,...
# 37  [feedback, crazy-8-brainstorming-template.html...
# 8   [Y3psTVNGaHlSR1UyV1ZjelJXSlpOVzVvTm1oaGEwOHZaM...
# 24  [42, all-of-these-are-true-regarding-correspon...
# 26  [v2, Jiaherb-v.-MTC-Industries.pdf, deposito-c...
# 31  [GkeGhwEA==&cacheHostOrigin=msedge.b.tlu.dl.de...
# 5   [amazonall_signin1.php, neEoaYpXd+kwzCw==&2dL=...
# 32  [ab4848d0-4d54-450d-b8aa-862d07295c83, 9cd4ecf...
# 34  [jl091hndgmp-201906, SlC8YvG07MiQGsW_nu0of5xJl...
# 30  [104fd7a0-08bc-47f7-ad91-a511d805c0cb, 0c7fac5...
# 3   [index.htm, /var/www/clean-mx/virusesevidence/...
# 10  [12, 10, img, www.lapeerhealth.com, pages_reco...
# 2   [page1.php, xn-magnifiques-sandales-comme-neuv...
# 27  [CjC4CKNVdg3dmwE96TtYV2dGiQGunR2rWiL3madOqvY_e...
# 36  [C:\Users\Admin\AppData\Local\Temp\22ifsbft.r3...
#
#    attributes.type_description attributes.type_extension first_submission_date
# 7                         HTML                      html   2022-06-17 00:23:38
# 11                        Text                       txt   2022-05-31 07:00:19
# 6                         HTML                      html   2022-05-06 06:46:36
# 14                        HTML                      html   2022-05-03 16:06:23
# 15                        HTML                      html   2022-04-26 12:01:39
# 9                         HTML                      html   2022-04-23 02:02:32
# 18                        HTML                      html   2022-04-21 13:42:23
# 19                        HTML                      html   2022-04-12 05:10:42
# 13                        HTML                      html   2022-04-06 22:31:23
# 16                  JavaScript                        js   2022-03-29 01:40:20
# 20                        HTML                      html   2022-03-20 16:04:13
# 12                        Text                       txt   2022-03-10 00:17:49
# 23                        HTML                      html   2022-01-09 20:23:48
# 29                        HTML                      html   2022-01-02 18:33:58
# 22                        HTML                      html   2021-12-21 10:00:08
# 17                        Text                       txt   2021-12-09 22:05:41
# 0                         HTML                      html   2021-10-06 08:49:30
# 33                        Text                       txt   2021-10-03 09:04:02
# 25                        HTML                      html   2021-09-13 01:28:42
# 28                        HTML                      html   2021-09-07 16:18:07
# 4                   JavaScript                        js   2021-07-03 07:22:34
# 21                        HTML                      html   2021-05-04 08:49:05
# 35                        Text                       txt   2020-09-04 19:13:42
# 38                        HTML                      html   2020-03-04 11:24:24
# 1                         HTML                      html   2019-11-07 06:28:25
# 37                        HTML                      html   2019-08-28 23:01:16
# 8                         HTML                      html   2019-06-06 07:51:38
# 24                        HTML                      html   2019-05-24 04:55:47
# 26                        HTML                      html   2019-03-10 23:45:20
# 31                        HTML                      html   2019-02-24 05:52:23
# 5                         HTML                      html   2019-01-22 09:35:35
# 32                        HTML                      html   2018-08-30 19:01:43
# 34                        HTML                      html   2018-08-29 05:28:08
# 30                        HTML                      html   2017-04-14 13:10:22
# 3                         HTML                      html   2017-03-14 06:44:52
# 10                        HTML                      html   2017-03-12 08:24:12
# 2                   JavaScript                        js   2009-10-19 20:34:00
# 27                        Text                       txt   2009-04-26 01:55:32
# 36                  JavaScript                        js   2008-05-01 01:30:22

# %% [markdown]
# Of course, this is just the beginning of our analysis! You could filter out files by number malicious ratings, filetype, or the submisison date
